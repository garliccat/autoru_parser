# %% [markdown]
# ## Auto.ru price predict with Random Forest

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Reading the dataset
# #### Dropping the title and models columns. There are too much models, and i think that Brand name is more valuable in considering the price of the car.

# %%
df = pd.read_csv('autoru_cleaned.csv', sep=';')
df = df.drop(['title', 'model'], axis=1)

# %% [markdown]
# ### Getting rid of elite and high society extra expensive cars

# %%
df = df[df['price'] < df['price'].quantile(0.95)]
df = df.reset_index(drop=True)
display(df.head())
print(df.shape)
# Out:
#    brand      gear     drive    color  year  mileage    price  eng_vol  hps  \
# 0     ac  механика    задний  красный  2001    13500  1800000      4.9  326
# 1  acura   автомат    полный    белый  2014   123060  2035000      3.5  290
# 2  acura   автомат    полный    серый  2014   135000  1650000      3.5  290
# 3  acura     робот  передний    серый  2015    44000  1700000      2.4  201
# 4  acura   автомат    полный    белый  2015    74551  2700000      3.5  290
#
#   gas_type
# 0   Бензин
# 1   Бензин
# 2   Бензин
# 3   Бензин
# 4   Бензин
# (60734, 10)

# %% [markdown]
# ### Melting the categorical columns into features

# %%
cat_columns = df.columns[df.dtypes == object].tolist()
enc = OneHotEncoder(handle_unknown='ignore')
enc_df = pd.DataFrame(enc.fit_transform(df[cat_columns]).toarray())
df_2 = df.drop(cat_columns, axis=1)
df_2 = df_2.join(enc_df)

# %%
X = df_2.drop('price', axis=1)
y = df_2['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ### Instantiate the model and parameters for grid-search

# %%
model = RandomForestRegressor()

parameters_for_testing = {
   'max_depth':range(3, 10),
   'n_estimators':range(100, 500, 100),
   'min_samples_split': [5],
   'max_depth': [6],
   }

# %% [markdown]
# ### Fitting the model. This will take a time (depends on grid search parameters quantity)

# %%
gsearch = GridSearchCV(estimator=model, 
                       param_grid=parameters_for_testing, 
                       n_jobs=-1, 
                       verbose=10)
gsearch.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done   8 out of  20 | elapsed:   37.8s remaining:   56.7s
# [Parallel(n_jobs=-1)]: Done  11 out of  20 | elapsed:  1.2min remaining:   59.7s
# [Parallel(n_jobs=-1)]: Done  14 out of  20 | elapsed:  1.5min remaining:   38.7s
# [Parallel(n_jobs=-1)]: Done  17 out of  20 | elapsed:  2.0min remaining:   20.8s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  2.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  2.2min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'max_depth': [6], 'min_samples_split': [5],
#                          'n_estimators': range(100, 500, 100)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=10)

# %%
print('Best params: {}'.format(gsearch.best_params_))
print('Best score: {}'.format(gsearch.best_score_))
# Out:
# Best params: {'max_depth': 6, 'min_samples_split': 5, 'n_estimators': 400}
# Best score: 0.8348214756673451

# %%
y_pred = gsearch.best_estimator_.predict(X_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.8331616885783106

# %%
sns.scatterplot(x=y_pred, y=y_test)
# Out:
# <AxesSubplot:ylabel='price'>

# %%
df_valid = pd.DataFrame.from_dict({'brand': ['mitsubishi'], 
    'gear': ['автомат'], 
    'drive': ['передний'], 
    'color': ['красный'], 
    'year': [2006], 
    'mileage': [230000], 
    'price': [250000], 
    'eng_vol': [1.6], 
    'hps': [60], 
    'gas_type': ['Бензин']})

# %%
enc_df_valid = pd.DataFrame(enc.transform(df_valid[cat_columns]).toarray())
df_valid = df_valid.drop(cat_columns, axis=1)
df_valid = df_valid.join(enc_df_valid)

# %%
X_valid = df_valid.drop('price', axis=1)
y_valid = df_valid['price']

# %%
y_predicted = gsearch.best_estimator_.predict(X_valid)
print('Predicted car price: {}'.format(y_predicted))
print('Actual car price: {}'.format(y_valid[0]));
# Out:
# Predicted car price: [167121.2030135]
# Actual car price: 250000
